# %% [markdown]
# # Содержание <a class="anchor" id="begining"></a>

# %% [markdown]
# <h1><span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Содержание-" data-toc-modified-id="Содержание--1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Содержание <a class="anchor" id="begining" rel="nofollow"></a></a></span></li><li><span><a href="#Анализ-бизнес-показателей-развлекательного-приложения-Procrastinate-Pro+" data-toc-modified-id="Анализ-бизнес-показателей-развлекательного-приложения-Procrastinate-Pro+-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ бизнес-показателей развлекательного приложения Procrastinate Pro+</a></span></li><li><span><a href="#Обзор-и-подготовка-данных." data-toc-modified-id="Обзор-и-подготовка-данных.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обзор и подготовка данных.</a></span><ul class="toc-item"><li><span><a href="#Изучение-структуры-датасетов" data-toc-modified-id="Изучение-структуры-датасетов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Изучение структуры датасетов</a></span></li><li><span><a href="#Оптимизация-данных-для-анализа" data-toc-modified-id="Оптимизация-данных-для-анализа-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Оптимизация данных для анализа</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Определение-функций-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Определение-функций-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Определение функций для расчета и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Добавим-функции-для-расчета-необходимых-нам-метрик" data-toc-modified-id="Добавим-функции-для-расчета-необходимых-нам-метрик-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Добавим функции для расчета необходимых нам метрик</a></span></li><li><span><a href="#Также-определим-функции-для-визуализации-метрик" data-toc-modified-id="Также-определим-функции-для-визуализации-метрик-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Также определим функции для визуализации метрик</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Построение-профилей-пользователей." data-toc-modified-id="Построение-профилей-пользователей.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Построение профилей пользователей.</a></span></li><li><span><a href="#Из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей" data-toc-modified-id="Из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей</a></span></li><li><span><a href="#Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи" data-toc-modified-id="Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи</a></span></li><li><span><a href="#Каналы,-из-которых-пришло-больше-всего-платящих-пользователей" data-toc-modified-id="Каналы,-из-которых-пришло-больше-всего-платящих-пользователей-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Каналы, из которых пришло больше всего платящих пользователей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-расходов-на-маркетинг" data-toc-modified-id="Анализ-расходов-на-маркетинг-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Анализ расходов на маркетинг</a></span><ul class="toc-item"><li><span><a href="#Распределение-расходов-на-маркетинг-по-времени-и-источникам" data-toc-modified-id="Распределение-расходов-на-маркетинг-по-времени-и-источникам-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Распределение расходов на маркетинг по времени и источникам</a></span></li><li><span><a href="#Стоимость-привлечения-одного-пользователя-из-каждого-источника" data-toc-modified-id="Стоимость-привлечения-одного-пользователя-из-каждого-источника-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Стоимость привлечения одного пользователя из каждого источника</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Итоги-исследования" data-toc-modified-id="Итоги-исследования-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Итоги исследования</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# #  Анализ бизнес-показателей развлекательного приложения Procrastinate Pro+

# %% [markdown]
# Несмотря на огромные вложения в рекламу, последние несколько месяцев компания, выпускающая приложение терпит убытки.
#
#
# **Цель исследования** - разобраться в причинах  и помочь компании выйти в плюс.
#
# **Задачи:**
# * Выделить причины неэффективности привлечения пользователей.
# * Выявить факторы, мешающие привлечению клиентов
# * Сформулировать рекомендации для отдела маркетинга.

# %% [markdown]
# **Ход исследования**
#
#  Исследование пройдёт в пять этапов:
#  1. Обзор и подготовка данных.
#  2. Определение функции для расчета и анализа LTV, ROI, удержания и конверсии.
#  3. Исследовательский анализ данных.
#  4. Анализ расходов на маркетинг.
#  5. Оценка окупаемости рекламы.

# %% [markdown]
# # Обзор и подготовка данных.

# %% [markdown]
# ## Изучение структуры датасетов

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Предварительно ознакомимся с данными из таблиц

# %% [markdown]
# **Описание данных**
#
# **Таблица `visits_log_short` (лог сервера с информацией о посещениях сайта):**
#
# `User Id` — уникальный идентификатор пользователя
#
# `Device` — категория устройства пользователя
#
# `Session start` — дата и время начала сессии
#
# `Session End` — дата и время окончания сессии
#
# `Channel` — идентификатор рекламного источника, из которого пришел пользователь
#
# `Region` - страна пользователя
#
#
#
# **Таблица `orders_log_short` (информация о заказах):**
#
#
# `User Id` — уникальный id пользователя, который сделал заказ
#
# `Event Dt` — дата и время покупки
#
# `Revenue` — выручка
#
#
# **Таблица `costs_short` (информация о затратах на маркетинг):**
#
#
# `Channel` — идентификатор рекламного источника
# `Dt` — дата
#
# `Costs` — затраты на этот рекламный источник в этот день

# %% [markdown]
# Положим данные о визитах, заказах и рекламных тратах в соответствующие переменные.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
# Информация о посещениях сайта
visits = pd.read_csv('visits_info_short.csv')

# %%
# Информация о заказах
orders = pd.read_csv('orders_info_short.csv')

# %%
# Информация о затратах на маркетинг
costs = pd.read_csv('costs_info_short.csv')

# %% [markdown]
# Теперь ознакомимся с содержанием таблиц

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Видим, что в во всех таблицах отсутствуют пропуски. Тем не менее кое-что нуждается в оптимизации:
#
# * столбцы с датами во всех таблицах требуется перевести в `datetime`
# * также для удобства названия столбцов можно привести к snake_case

# %% [markdown]
# ## Оптимизация данных для анализа

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Для начала скорректируем названия столбцов

# %%
# # Приведение столбцов к нижнему регистру
tables = {'visits': visits, 'costs': costs, 'orders': orders}
# for table in tables.values():
#     for col in table.columns:
#         good_col = col.lower()
#         table.rename(columns={col:good_col}, inplace=True)

# %%
# Приведение названий столбцов к snake_case
visits.columns = visits.columns.str.lower().str.replace(' ', '_')
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
costs.columns = costs.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# Теперь проверим каждую таблицу на наличие явных дубликатов

# %%
for name, table in tables.items():
    print(f'В таблице {name}  {table.duplicated().sum()} дубликатов')
# Out:
# В таблице visits  0 дубликатов
# В таблице costs  0 дубликатов
# В таблице orders  0 дубликатов

# %% [markdown]
# Дубликатов не обнаружено.
#
# Наконец переведем значения столбцов с датами во всех таблицах в формат `datetime`

# %%
# преобразование данных о времени
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
# Проверка результата
for i in tables.values():
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# ## Вывод

# %% [markdown]
# Теперь данные подготовлены и оптимизированы для дальнейшего анализа. Все значения приведены к нужным форматам, названия столбцов для удобства приведены к snake_case

# %% [markdown]
# # Определение функций для расчета и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# ## Добавим функции для расчета необходимых нам метрик

# %% [markdown]
# [К содержанию](#begining)

# %%
[К содержанию](#begining)# функция для создания пользовательских профилей

def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ## Также определим функции для визуализации метрик

# %% [markdown]
# [К содержанию](#begining)

# %%
[К содержанию](#begining)# функция для сглаживания получаемых графиков

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Вывод

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Таким образом, в нашем распоряжении есть все необходимые инструменты, для анализа бизнес показателей приложения

# %% [markdown]
# #  Исследовательский анализ данных
#
#
#
# Попробуем выяснить:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# Но для начала построим пользовательские профили, которые будут использоваться в рамках дальнейшего исследования.

# %% [markdown]
# ## Построение профилей пользователей.

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Для создания профилей пользователей применим функцию `get_profiles()`

# %%
profiles = get_profiles(sessions=visits, orders=orders, events=[], ad_costs=costs, event_names=[])
profiles.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %% [markdown]
# Также необходимо определиться с минимальной и максимальной датой привлечения пользователей (она же является моментом анализа).

# %%
min_analysis_date = profiles['dt'].min()
observation_date =  profiles['dt'].max()
print(f'Минимальная дата привлечения пользователей: {min_analysis_date}')
print(f'Максимальная дата привлечения пользователей: {observation_date}')
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# ## Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Чтобы ответить на этот вопрос, сгруппируем таблицу с профилями пользователей по стране и с сортировкой по долей платящих пользователей

# %%
(profiles
         .pivot_table(index='region', values='payer', aggfunc=['count', 'sum', 'mean'])
         .reset_index()
         .rename(columns={'count': 'all_users', 'sum': 'paying_users', 'mean': 'ratio'})
         .droplevel(1, axis=1) 
         .sort_values(by='ratio', ascending=False)
         .style.format({'ratio': '{:.2%}'})
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a5c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a5c9_level0_col0" class="col_heading level0 col0" >region</th>
#       <th id="T_9a5c9_level0_col1" class="col_heading level0 col1" >all_users</th>
#       <th id="T_9a5c9_level0_col2" class="col_heading level0 col2" >paying_users</th>
#       <th id="T_9a5c9_level0_col3" class="col_heading level0 col3" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a5c9_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_9a5c9_row0_col0" class="data row0 col0" >United States</td>
#       <td id="T_9a5c9_row0_col1" class="data row0 col1" >100002</td>
#       <td id="T_9a5c9_row0_col2" class="data row0 col2" >6902</td>
#       <td id="T_9a5c9_row0_col3" class="data row0 col3" >6.90%</td>
#     </tr>
#     <tr>
#       <th id="T_9a5c9_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# Как видим, подавляющее большинство польщоватлей нашего приложения - из США. Они же, около 7% из них, чаще всего совершают покупки, по сравнению с пользователями из других стран.

# %% [markdown]
# ## Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Чтобы ответить на этот вопрос, сгруппируем таблицу с профилями пользователей по типу устройства и вновь отсортируем ее по доле платящих пользователей

# %%
(profiles
         .pivot_table(index='device', values='payer', aggfunc=['count', 'sum', 'mean'])
         .reset_index()
         .rename(columns={'count': 'all_users', 'sum': 'paying_users', 'mean': 'ratio'})
         .droplevel(1, axis=1) 
         .sort_values(by='ratio', ascending=False)
         .style.format({'ratio': '{:.2%}'})
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f465a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f465a_level0_col0" class="col_heading level0 col0" >device</th>
#       <th id="T_f465a_level0_col1" class="col_heading level0 col1" >all_users</th>
#       <th id="T_f465a_level0_col2" class="col_heading level0 col2" >paying_users</th>
#       <th id="T_f465a_level0_col3" class="col_heading level0 col3" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f465a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f465a_row0_col0" class="data row0 col0" >Mac</td>
#       <td id="T_f465a_row0_col1" class="data row0 col1" >30042</td>
#       <td id="T_f465a_row0_col2" class="data row0 col2" >1912</td>
#       <td id="T_f465a_row0_col3" class="data row0 col3" >6.36%</td>
#     </tr>
#     <tr>
#       <th id="T_f465a_level0_row1" class="row_heading level0 row1" >3</th>
# ...

# %% [markdown]
# * Большинство наших пользователей - владельцы айфонов. Остальные устройства пользуются примерно сопоставимой популярностью.
#
#
# * Судя по таблице, платящие пользователи предпочитают технику Apple - владельцы iPhone и Mac совершают покупки чуть более чем в 6% случаях.

# %% [markdown]
# ## Каналы, из которых пришло больше всего платящих пользователей

# %% [markdown]
# [К содержанию](#begining)

# %%
[К содержанию](#begining)(profiles
         .pivot_table(index='channel', values='payer', aggfunc=['count', 'sum', 'mean'])
         .reset_index()
         .rename(columns={'count': 'all_users', 'sum': 'paying_users', 'mean': 'ratio'})
         .droplevel(1, axis=1) 
         .sort_values(by='ratio', ascending=False)
         .style.format({'ratio': '{:.2%}'})
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e5aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e5aa_level0_col0" class="col_heading level0 col0" >channel</th>
#       <th id="T_0e5aa_level0_col1" class="col_heading level0 col1" >all_users</th>
#       <th id="T_0e5aa_level0_col2" class="col_heading level0 col2" >paying_users</th>
#       <th id="T_0e5aa_level0_col3" class="col_heading level0 col3" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e5aa_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0e5aa_row0_col0" class="data row0 col0" >FaceBoom</td>
#       <td id="T_0e5aa_row0_col1" class="data row0 col1" >29144</td>
#       <td id="T_0e5aa_row0_col2" class="data row0 col2" >3557</td>
#       <td id="T_0e5aa_row0_col3" class="data row0 col3" >12.20%</td>
#     </tr>
#     <tr>
#       <th id="T_0e5aa_level0_row1" class="row_heading level0 row1" >0</th>
# ...

# %% [markdown]
# * С наибольшей охотой совершают покупки те, кто пришел из FaceBoom, AdNonSense, lambdaMediaAds.
#
#
# * С наименьшей - пользователи из OppleCreativeMedia, LeapBob, MediaTornado, YRabbit. Ну и органические пользователи само собой.

# %% [markdown]
# ## Вывод

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# * В рамках этого шага были построены пользовательские профили, которые будут использоваться в рамках дальнейшего исследования.
#
#
# * Большинство пользоватлей нашего приложения (около 66%) - из США. Они же, примерно 7% из них, чаще всего совершают покупки, по сравнению с пользователями из других стран.
#
#
# * Большинство наших пользователей - владельцы айфонов. Остальные устройства пользуются примерно сопоставимой популярностью.
#
#
# * Судя по таблице, платящие пользователи предпочитают технику Apple - владельцы iPhone и Mac совершают покупки чуть более чем в 6% случаях.
#
#
# * С наибольшей охотой совершают покупки те, кто пришел из каналов FaceBoom, AdNonSense, lambdaMediaAds.
#
#
# * С наименьшей, помимо органических пользователей, - пользователи из OppleCreativeMedia, LeapBob, MediaTornado, YRabbit.

# %% [markdown]
# # Анализ расходов на маркетинг

# %% [markdown]
# ## Распределение расходов на маркетинг по времени и источникам

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Для начала посмотрим какое количество средств было потрачено всего на каждый источник.

# %%
# распределение расходов по источникам
costs_report = costs.groupby('channel', as_index=False).agg({'costs': 'sum'})
costs_report.sort_values(by='costs', ascending=False, inplace=True)
costs_report.reset_index(inplace=True, drop=True)
costs_report['costs'] = costs_report['costs'].round().astype('int')
costs_report
# Out:
#               channel  costs
# 0              TipTop  54751
# 1            FaceBoom  32446
# 2      WahooNetBanner   5151
# 3          AdNonSense   3911
# 4  OppleCreativeMedia   2151
# 5      RocketSuperAds   1833
# 6             LeapBob   1798
# 7      lambdaMediaAds   1558
# 8        MediaTornado    954
# 9             YRabbit    944

# %%
# Общая сумма расходов на маркетинг 
costs_report.costs.sum().round()
# Out:
# 105497

# %%
# Визуализация расходов по источникам
sns.set(style='darkgrid', font_scale=1.3)
plt.figure(figsize=(22,8))
sns.barplot(x='channel', y='costs', data=costs_report).set_title('Сумма расходов на рекламу по разным источникам')
plt.xlabel('Канал')
plt.ylabel('Сумма расходов');

# %% [markdown]
# * Из 105 тыс. уе больше половины ушло на рекламу в TipTop. Около трети - на рекламу в FaceBoom.
#
#
# * Наиболее обделенные вниманием рекламные источники - lambdaMediaAds, MediaTornado и YRabbit, в сумме на них было потрачено меньше, чем, например, на WahooNetBanner, который является третьим каналом пообъему расходов.

# %%
# Визуализация изменения расходов во времени
report = costs.copy()
report = report[costs['channel'].isin(costs_report['channel'])]
report['costs'] = report['costs'].rolling(window=7).mean()

plt.figure(figsize=(15, 10))
plt.title('Динамика изменения расходов на маркетинг по разным источникам')
plt.xlabel('Даты')
plt.ylabel('Расходы на маркетинг')
(sns.lineplot(
    x='dt', 
    y='costs',
    hue='channel',
    data=report
    ));

# %% [markdown]
# Также добавим визуализацию динамики маркетинговых расходов по месяцам

# %%
# Группировка по месяцам
report = costs.copy()
report['dt'] = report['dt'].astype('datetime64[M]')
report = report.groupby('dt').agg({'costs': 'sum'})
report.reset_index(inplace=True)
report
# Out:
#           dt      costs
# 0 2019-05-01   9978.570
# 1 2019-06-01  15090.045
# 2 2019-07-01  16447.060
# 3 2019-08-01  20657.870
# 4 2019-09-01  22441.340
# 5 2019-10-01  20882.415

# %%
# Визуализация динамики изменения расходов по месяцам
plt.figure(figsize=(10, 6))
plt.title('Общая сумма расходов на маркетинг помесячно')
plt.xlabel('Месяц')
plt.ylabel('Сумма расходов')
(sns.lineplot(
    x='dt', 
    y='costs',
    data=report
    ));

# %% [markdown]
# По графику динамики расходов на рекламу видим, что в последние месяцы существенно увеличились расходы в первую очередь на 2 источника - TipTop и FaceBoom.
#
#
# Насколько эффективными оказались эти вложения покажут следующие разделы данного исследования.

# %% [markdown]
# ## Стоимость привлечения одного пользователя из каждого источника

# %% [markdown]
# [К содержанию](#begining)

# %%
# Средняя стоимость привлечения одного пользователя для всего проекта в целом
profiles.acquisition_cost.sum() / profiles.user_id.count()
# Out:
# 0.7032778251826568

# %%
# Средняя стоимость привлечения одного пользователя по каждому источнику
cac_table = profiles.groupby('channel').agg({'user_id': 'nunique', 'acquisition_cost': 'sum'})
cac_table['cac'] = cac_table.acquisition_cost / cac_table.user_id
cac_table.sort_values(by='cac', ascending=False, inplace=True)
cac_table
# Out:
#                     user_id  acquisition_cost       cac
# channel
# TipTop                19561          54751.30  2.799003
# FaceBoom              29144          32445.60  1.113286
# AdNonSense             3880           3911.25  1.008054
# lambdaMediaAds         2149           1557.60  0.724802
# WahooNetBanner         8553           5151.00  0.602245
# RocketSuperAds         4448           1833.00  0.412095
# OppleCreativeMedia     8605           2151.25  0.250000
# YRabbit                4312            944.22  0.218975
# MediaTornado           4364            954.48  0.218717
# LeapBob                8553           1797.60  0.210172
# organic               56439              0.00  0.000000

# %% [markdown]
# TipTop, FaceBoom и AdNonSense являются самыми дорогими каналами привлечения новых пользователей. САС у всех троих значительно превышает среднюю стоимость привлечения одного пользователя по всем источникам.

# %% [markdown]
# ## Вывод

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# * Подавляющее большинство всех средств, пущенных на рекламу, было потрачено на каналы **TipTop и FaceBoom - в сумме на них приходится около 83% от всех затрат на маркетинг.**
#
#
# * При этом  в последние месяцы  расходы  на эти 2 источника значительно возросли.
#
#
# * Вследствие этого, те же TipTop, FaceBoom, а так примкнувший к ним AdNonSense являются самыми дорогими каналами привлечения новых пользователей. САС у всех троих значительно превышает стоимость привлечения одного пользователя по всем источникам в среднем.
#
#
# * Наиболее обделенные вниманием рекламные источники - **lambdaMediaAds, MediaTornado и YRabbit, в сумме на них приходится только чуть более 3% от всех затрат на маркетинг.**
#
#
# * Самые "дешевые" пользователи - у каналов LeapBob, MediaTornado, YRabbit и OppleCreativeMedia. Но стоит отметить, что из этих же каналов приходят  наименее платящие пользователи.

# %% [markdown]
# # Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Для начала установим горизонт и момент анализа данных с учетом того, что мы смотрим данные 1-го ноября 2019 года, и  вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %%
horizon = 14
observation_date = datetime(2019, 11, 1).date()

# %% [markdown]
# Также исключим из таблицы профилей органических пользователей - поскольку мы за них ничего не платим, а нам необходимо изучить именно окупаемость рекламы.

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# ## Анализ общей окупаемости рекламы

# %% [markdown]
# Для анализа общей окупаемости рекламы построим  графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# расчет метрик
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles, orders, observation_date, horizon)

# построение графиков
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon)

# %% [markdown]
# * Видим, что реклама не окупается. К концу второй недели ROI около 80%
#
#
# * На LTV влияет сезонный фактор, однако колебания этой метрики  достаточно стабильны. Значит, дело не в ухудшении качества пользователей.
#
#
# * При этом САС постепенно увеличивается, что говорит о том, что компания в последнее время действительно значительно увеличила расходы на рекламу.
#
#
# * Складывается впечатление, что рост расходов на рекламу негативно влияет на динамику ROI на 14 день.  В начале исследуемого периода этот показатель был значимо выше границы окупаемости, а ближе к моменту анализа значительно просел.

# %% [markdown]
# Чтобы разобраться, почему затраты на рекламу не окупаются, изучим  все доступные характеристики пользователей —  их регион, источник и устройство первого посещения.

# %% [markdown]
# ## Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Начнем с разбивки по устройствам, для этого передадим в параметр `dimesnsion` столбец `device`

# %%
# расчет метрик
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles, orders, observation_date, horizon, ['device'])

# построение графиков
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon)

# %% [markdown]
# * Реклама в целом окупается только для пользователей ПК. Однако, если смотреть на динамику ROI на 14 день, то для последних когорт реклама не окупается уже нигде.
#
#
# * Не окупаются Mac, iPhone и Android. При этом именно у этих устройств самая дорогая стоимость привлечения пользователя.
#
#
# * На ПК показатель стоимость привлечения пользователя наименьшая, по сравнению с остальными устройствами, что может говорить о взаимосвязи между этими показателями.
#
#
# * В целом, несмотря на то, что САС со временем увеличивается для всех платформ, уровень окупаемости на всех устройствах постепенно снижается к моменту анализа.

# %% [markdown]
# Проверим, отличается ли как-то удержание и конверсия для пользователей разных устройств.  Возможно эти метрики способны пролить свет на причину низкого ROI у пользователей мобильных устройств.

# %%
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon, ['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon)

# %% [markdown]
# Причина определенно не в конверсии - пользователи Mac, iPhone и Android конвертируются лучше всего. Быть может дело все-таки в удержании?

# %%
# проверяем удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon, ['device']
)

plot_retention(retention_grouped, retention_history, horizon)

# %% [markdown]
# Причина так и не обнаружена - любители "проблемной" техники удерживаются не сильно хуже других. Остается только продолжать поиски объяснений уже в разбивке по другим характеристикам.

# %% [markdown]
# ## Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Теперь посмотрим на разбивку по странам

# %%
# расчет метрик
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles, orders, observation_date, horizon, ['region'])

# построение графиков
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon)

# %% [markdown]
# * Видим, что реклама окупается везде, кроме одной единственной страны - США.
#
#
# * Стоимость привлечения американских пользователей в несколько раз выше, чем пользователей из других стран, при этом самый высокий LTV - также у пользователей из США. Вероятно причина низкого ROI именно в дороговизне американских пользователей.
#
#
# * Отметим также, что за последнее время САС американских пользователей существенно вырос, а у пользователей из других стран, наоборот, снизился. Так что, вероятнее здесь замешаны  каналы привлечения новых пользователей.

# %% [markdown]
# Также посмотрим на конверсию и удержание

# %%
# смотрим конверсию с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon, ['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon)

# %% [markdown]
# Американские пользователи лидеры по конверсии с гигантским отрывом. Дело явно не в этом.

# %%
# проверяем удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon, ['region']
)

plot_retention(retention_grouped, retention_history, horizon)

# %% [markdown]
# * К концу второй недели платящие пользователи из США удерживаются заметно хуже, чем пользователи из других стран. Без данных о событиях сложно говорить о том, в чем может быть причина.
#
#
# * Однако можно предположить, что ситуация с пользователями из США как-то связана с низким ROI владельцев айфонов и маков. Проверим эту гипотезу

# %%
# Самые популярные устройства в США
sample = profiles.copy()
sample.query('region == "United States"')['device'].value_counts()
# Out:
# iPhone     27548
# Mac        15424
# Android    12436
# PC          6421
# Name: device, dtype: int64

# %%
# Самые популярные устройства в других странах
sample.query('region != "United States"')['device'].value_counts()
# Out:
# PC         12732
# Android     9405
# iPhone      6334
# Mac         3269
# Name: device, dtype: int64

# %% [markdown]
# Гипотеза подтвердилась. Яблочные устройства пользуются наибольшей популярностью именно в  США, где ими пользуются почти 68% пользователей, в то время как в других странах из распространенность значительно меньше - около 30%.
#
#
# Таким образом, причины низкого ROI жителей Америки и владельцев техники Apple взаимосвязаны. Однако конкретную причину сложно установить без дополнительной информации.

# %% [markdown]
# ## Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Наконец посмотрим, как на окупаемость рекламы влияют различные каналы привлечения пользователей.

# %%
# при первоначальном построении графиков цвет линии органических пользователей совпадал с одним из каналов. 
#по этой причине было решено убрать их из графиков 


# расчет метрик
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles, orders, observation_date, horizon, ['channel'])

# убираем последнюю строку с органическими польщователями
non_organic = non_organic = ltv_grouped.copy()[:-1]

# построение графиков
plot_ltv_roi(non_organic, ltv_history, roi_grouped, roi_history, horizon)

# %% [markdown]
# * Из всех каналов к концу второй недели не окупаются только 3 - **TipTop, AdNonSense, FaceBoom**
#
#
# * Эти же каналы являются самыми дорогими с точки зрения стоимости новых пользователей. Особенно выделяется TipTop, в котором показатель САС за 5 месяцев вырос более чем в 3 раза.
#
#
# * При этом показатель LTV у TipTop один из лучших. Так что вроятнее всего, **причина низкого ROI у TipTop - слишком высокая стоимость привлечения новых пользователей.**
#
#
# * **Лучше же всего окупаются lambdaMediaAds, YRabbit и MediaTornado**. Учитывая, что САС у них значительно чем у трех упомянутых каналов, стоит порекомендовать отделу маркетинга активнее работать именно с данными каналами.

# %% [markdown]
# Попробуем разобраться в чем дело у двух других проблемных каналов при помощи графиков конверсии и удержания

# %%
# смотрим конверсию с разбивкой по каналам

# убираем органических пользователей
non_organic = profiles.copy().query('channel != "organic"')

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    non_organic, orders, observation_date, horizon, ['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon)

# %% [markdown]
# Конверсия у трех упомянутых каналов одна из лучших. Значит, дело не в ней

# %%
# проверяем удержание с разбивкой по каналам

retention_raw, retention_grouped, retention_history = get_retention(
    non_organic, visits, observation_date, horizon, ['channel']
)

plot_retention(retention_grouped, retention_history, horizon)

# %% [markdown]
# У двух из упомянутых каналов - AdNonSense и FaceBoom абсолютно худшие показатели удержания.
#
# Проверим с чем это может быть связано. Возможно дело в устройствах или регионах, на которые оринтированы эти каналы

# %%
# таблица канал - пользовательское устройство
channels =  profiles.pivot_table(index='channel', columns='device', values='user_id', aggfunc='count')
channels.reset_index(inplace=True)
channels.query('channel == "AdNonSense" or channel == "FaceBoom" or channel == "TipTop"')
# Out:
# device     channel  Android   Mac    PC  iPhone
# 0       AdNonSense     1109   410  1563     798
# 1         FaceBoom     5875  7265  3008   12996
# 6           TipTop     3889  4820  2012    8840

# %%
# таблица канал - регион пользователя
channels =  profiles.pivot_table(index='channel', columns='region', values='user_id', aggfunc='count')
channels.reset_index(inplace=True)
channels.query('channel == "AdNonSense" or channel == "FaceBoom" or channel == "TipTop"')
# Out:
# region     channel  France  Germany      UK  United States
# 0       AdNonSense  1366.0   1219.0  1295.0            NaN
# 1         FaceBoom     NaN      NaN     NaN        29144.0
# 6           TipTop     NaN      NaN     NaN        19561.0

# %% [markdown]
# * Видим, что  самый дорогой канал привлечения **TipTop** ориентирован исключительно на американских пользователей. Это объясняет, почему САС пользщователей из США был в несколько раз выше, чем у других.
#
#
# * Через канал **FaceBoom**v  приходили только американцы, преимущественно владеющие техникой Apple. Именно у этих категорий мы наблюдали проблемы с окупаемостью и удержанием.
#
#
# * Причину низкого удержания канала **AdNonSense** проблематично установить без дополнительных данных.

# %% [markdown]
# ## Вывод

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# * Анализ общей окупаемости рекламы показал, что реклама не окупается. К концу второй недели ROI около 80%.
#
#
# * При этом стоимость привлечения новых пользователей постепенно увеличивается, что говорит о том, что компания в последнее время действительно значительно увеличила расходы на рекламу.
#
#
# * Рост расходов на рекламу вероятно негативно влияет на динамику ROI на конец второй недели. В начале исследуемого периода этот показатель был значимо выше границы окупаемости, а ближе к моменту анализа значительно просел.
#
#
# * В разбивке по устройствам, несмотря на лучшие показатели конверсии не окупаются Mac, iPhone и Андроид. При этом именно у этих устройств самая дорогая стоимость привлечения пользователя.
#
#
# * В разбивке по странам реклама окупается везде, кроме США. Стоимость привлечения американских пользователей в несколько раз выше, чем пользователей из других стран, при этом самый высокий LTV - также у пользователей из США. Вероятно одна из причин низкого ROI именно в дороговизне американских пользователей.
#
#
# * Американские пользователи лидеры по конверсии с гигантским отрывом. При этом концу второй недели платящие пользователи из США удерживаются заметно хуже, чем пользователи из других стран.
#
#
# * Вероятно на низкая окупаемость американских пользователей и владельцев устройств Apple взаимосвязана. Яблочные устройства пользуются наибольшей популярностью именно в США, где ими пользуются почти 70% пользователей, в то время как в других странах из распространенность значительно меньше - около 30%. Однако конкретную первопричину сложно установить без дополнительной информации, например, данных из журнала событий.
#
#
# * Из всех каналов к концу второй недели не окупаются только 3 - TipTop, AdNonSense, FaceBoom. Эти же каналы являются самыми дорогими с точки зрения стоимости новых пользователей. У двух из упомянутых каналов - AdNonSense и FaceBoom к тому же еще и абсолютно худшие показатели удержания.
#
#
# * Особенно выделяется TipTop, в котором показатель САС за 5 месяцев вырос более чем в 3 раза.
# При этом показатель LTV у TipTop один из лучших. Так что вроятнее всего, причина низкого ROI у TipTop - слишком высокая стоимость привлечения новых пользователей.
#
#
# * Лучше же всего окупаются lambdaMediaAds, YRabbit и MediaTornado.

# %% [markdown]
# # Итоги исследования

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# Работа над данным исследованием включала в себя последовательное выполнение следующих задач.
#
# На **первом этапе** в ходе предварительного обзора  данные были подготовлены и оптимизированы для дальнейшего анализа. Все значения приведены к нужным форматам, названия столбцов для удобства приведены к snake_case.
#
#
# На **втором этапе** были определены функции для расчета и анализа LTV, ROI, удержания и конверсии, а также функции для построения соответствующих графиков.
#
#
# В ходе **третьего этапа** был проведен исследовательский анализ данных, который показал следующее:
#
#
# * Большинство пользоватлей нашего приложения (около 66%) - из США. Они же, примерно 7% из них, чаще всего совершают покупки, по сравнению с пользователями из других стран.
#
# * Большинство наших пользователей - владельцы айфонов. Остальные устройства пользуются примерно сопоставимой популярностью.
#
# * Судя по таблице, платящие пользователи предпочитают технику Apple - владельцы iPhone и Mac совершают покупки чуть более чем в 6% случаях.
#
# * С наибольшей охотой совершают покупки те, кто пришел из каналов FaceBoom, AdNonSense, lambdaMediaAds.
#
# * С наименьшей, помимо органических пользователей, - пользователи из OppleCreativeMedia, LeapBob, MediaTornado, YRabbit.
#
#
# В рамках **четвертого этапа** на основе имеющихся данных был осуществлен анализ расходов на маркетинг, было выявлено что:
#
#
# * Подавляющее большинство всех средств, пущенных на рекламу, было потрачено на каналы **TipTop и FaceBoom - в сумме на них приходится около 83% от всех затрат на маркетинг.**  При этом  в последние месяцы  расходы  на эти 2 источника значительно возросли.
#
#
# * Вследствие этого, те же TipTop, FaceBoom, а так примкнувший к ним AdNonSense являются самыми дорогими каналами привлечения новых пользователей. САС у всех троих значительно превышает стоимость привлечения одного пользователя по всем источникам в среднем.
#
#
# * Наиболее обделенные вниманием рекламные источники - **lambdaMediaAds, MediaTornado и YRabbit, в сумме на них приходится только чуть более 3% от всех затрат на маркетинг.**
#
#
# * Самые "дешевые" пользователи - у каналов LeapBob, MediaTornado, YRabbit и OppleCreativeMedia. Однако,  из этих же каналов приходят  наименее платящие пользователи.
#
#
# Наконец, на **заключительном этапе** была произведена оценка окупаемости рекламы для привлечения пользователей. Анализ показал, что:
#
#
# * Реклама не окупается. К концу второй недели ROI вплотную подбирается к границе окупаемости, но так и не переходит через нее.
#
#
# * В разбивке по устройствам, несмотря на лучшие показатели конверсии не окупаются Mac и iPhone. При этом именно у этих устройств самая дорогая стоимость привлечения пользователя.
#
#
# * В разбивке по странам реклама окупается везде, кроме США. Стоимость привлечения американских пользователей в несколько раз выше, чем пользователей из других стран, при этом самый высокий LTV - также у пользователей из США.
#
#
# * Из всех каналов к концу второй недели не окупаются только 3 - TipTop, AdNonSense, FaceBoom. Эти же каналы являются самыми дорогими с точки зрения стоимости новых пользователей. У двух из упомянутых каналов - AdNonSense и FaceBoom к тому же еще и абсолютно худшие показатели удержания.

# %% [markdown]
# # Общий вывод

# %% [markdown]
# [К содержанию](#begining)

# %% [markdown]
# * Таким образом,главная причина убытков нашей компании в последние месяцы - высокая стоимость привлечения пользователей (стремительно возросшая за последнее время) и низкое удержание пользователей из США, которые несмотря на  высокую конверсию по какой-то причине довольно быстро теряют интерес к нашему продукту.
#
#
# * Возможно имеет смысл переорентироваться на каналы, которые лучше окупаются, но по каким-то причинам слабо используются нашим меркетинговым отделом - lambdaMediaAds, YRabbit и MediaTornado. Учитывая, что САС у них значительно ниже чем у трех "проблемных" каналов, стоит порекомендовать отделу маркетинга активнее работать именно с данными каналами.
#
#
# * Дороговизна привлечения новых пользователей не объясняет причину низкого удержания пользователей из США. Учитывая, что данная категория пользователей составляет 66% от всех наших клиентов а также обладает самым высоким LTV, необходимо уделить им особое внимание и как можно скорее разобраться в причинах подобной ситуации.
